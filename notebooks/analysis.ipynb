# %% [markdown]
# # Case Study Data Analysis
#
# Use this notebook to load, explore, and visualise your data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inline
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Example: df = pd.read_csv('../data/your-file.csv')

# %% [markdown]
# ## Explore Data

# %%
# df.head()
# df.describe()
# df.info()

# %% [markdown]
# ## Visualise
